# %%
import xarray as xr
import matplotlib.pyplot as plt

with xr.open_dataset('/home/arawlins/Downloads/IDV71117_VIC_FFDI_SFC.nc.gz') as ds:
    plt.imshow(ds['FFDI_SFC'].isel(time=1))
    plt.show()

# %%
# !pip install flask

# !pip install flask_restful
# !pip install flask_jsonpify
# Out:
# Collecting flask_restful
#   Downloading Flask_RESTful-0.3.6-py2.py3-none-any.whl
# Collecting aniso8601>=0.82 (from flask_restful)
#   Downloading aniso8601-1.3.0.tar.gz (57kB)
#     100% |████████████████████████████████| 61kB 4.3MB/s ta 0:00:01
# Requirement already satisfied: six>=1.3.0 in /opt/anaconda3/lib/python3.6/site-packages (from flask_restful)
# Requirement already satisfied: Flask>=0.8 in /opt/anaconda3/lib/python3.6/site-packages (from flask_restful)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.6/site-packages (from flask_restful)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.6/site-packages (from aniso8601>=0.82->flask_restful)
# Requirement already satisfied: Werkzeug>=0.7 in /opt/anaconda3/lib/python3.6/site-packages (from Flask>=0.8->flask_restful)
# Requirement already satisfied: Jinja2>=2.4 in /opt/anaconda3/lib/python3.6/site-packages (from Flask>=0.8->flask_restful)
# Requirement already satisfied: itsdangerous>=0.21 in /opt/anaconda3/lib/python3.6/site-packages (from Flask>=0.8->flask_restful)
# Requirement already satisfied: click>=2.0 in /opt/anaconda3/lib/python3.6/site-packages (from Flask>=0.8->flask_restful)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.6/site-packages (from Jinja2>=2.4->Flask>=0.8->flask_restful)
# Building wheels for collected packages: aniso8601
#   Running setup.py bdist_wheel for aniso8601 ... done
#   Stored in directory: /home/arawlins/.cache/pip/wheels/e3/6a/48/e4f2d89ff4146557cae20b77a9af7b4d09dd47b2004133cd7e
# Successfully built aniso8601
# Installing collected packages: aniso8601, flask-restful
# Successfully installed aniso8601-1.3.0 flask-restful-0.3.6
# Collecting flask_jsonpify
#   Downloading Flask-Jsonpify-1.5.0.tar.gz
# Requirement already satisfied: Flask in /opt/anaconda3/lib/python3.6/site-packages (from flask_jsonpify)
# Requirement already satisfied: Werkzeug>=0.7 in /opt/anaconda3/lib/python3.6/site-packages (from Flask->flask_jsonpify)
# Requirement already satisfied: Jinja2>=2.4 in /opt/anaconda3/lib/python3.6/site-packages (from Flask->flask_jsonpify)
# Requirement already satisfied: itsdangerous>=0.21 in /opt/anaconda3/lib/python3.6/site-packages (from Flask->flask_jsonpify)
# Requirement already satisfied: click>=2.0 in /opt/anaconda3/lib/python3.6/site-packages (from Flask->flask_jsonpify)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.6/site-packages (from Jinja2>=2.4->Flask->flask_jsonpify)
# Building wheels for collected packages: flask-jsonpify
#   Running setup.py bdist_wheel for flask-jsonpify ... done
#   Stored in directory: /home/arawlins/.cache/pip/wheels/94/49/b1/376d04c3136a18e59dbda03d7c5dd5d242e1035372b6703076
# Successfully built flask-jsonpify
# Installing collected packages: flask-jsonpify
# Successfully installed flask-jsonpify-1.5.0

# %%
from fuel_model import DeadFuelModel
from fuel_datastore import DataStore
from fuel_utils import FileNameWrangler

from IPython.display import display

# Formats & Plotting
import matplotlib.pyplot as plt
import pyproj as proj
import matplotlib
from matplotlib import cm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-e3cebe24085f> in <module>()
# ----> 1 from fuel_model import DeadFuelModel
#       2 from fuel_datastore import DataStore
#       3 from fuel_utils import FileNameWrangler
#       4
#       5 from IPython.display import display
#
# /media/arawlins/Data/UOM/lfmc-pipeline/fuel_model.py in <module>()
#       8 from flask_restful import Resource
#       9 from flask_jsonpify import jsonify
# ---> 10 from fuel_datastore import DataStore, Saver
#      11 import rasterio
#      12 from pathlib2 import Path
#
# /media/arawlins/Data/UOM/lfmc-pipeline/fuel_datastore.py in <module>()
#       5 import xarray as xr
#       6 from datetime import datetime
# ----> 7 from fuel_collector import Collector
#       8 import netCDF4 as nc4
#       9 from abc import abstractmethod
#
# /media/arawlins/Data/UOM/lfmc-pipeline/fuel_collector.py in <module>()
#       5 from urllib.error import URLError
#       6 import subprocess
# ----> 7 import rasterio
#       8 import multiprocessing
#       9 from fuel_utils import FileNameWrangler, TimeWrangler
#
# /opt/anaconda3/lib/python3.6/site-packages/rasterio/__init__.py in <module>()
#      13 import warnings
#      14
# ---> 15 from rasterio._base import (
#      16     eval_window, window_shape, window_index, gdal_version)
#      17 from rasterio.dtypes import (
#
# ImportError: /opt/anaconda3/lib/python3.6/site-packages/rasterio/../../.././libkea.so.1.4: undefined symbol: _ZN2H56H5FileC1ERKSsjRKNS_17FileCreatPropListERKNS_15FileAccPropListE

# %%
nolan = DeadFuelModel()
# Out:
# Loading init data
# Loading...
# For years:2015 to 2017
# Compiling dataset.
# Incomplete data for  2015
# Ingesting data for  2015
# Ingesting dfmc data for: 01/01/2015
# Ingesting dfmc data for: 02/01/2015
# Ingesting dfmc data for: 03/01/2015
# Ingesting dfmc data for: 04/01/2015
# Ingesting dfmc data for: 05/01/2015
# Ingesting dfmc data for: 06/01/2015
# Ingesting dfmc data for: 07/01/2015
# Ingesting dfmc data for: 08/01/2015
# Ingesting dfmc data for: 09/01/2015
# Ingesting dfmc data for: 10/01/2015
# Ingesting dfmc data for: 11/01/2015
# Ingesting dfmc data for: 12/01/2015
# Ingesting dfmc data for: 13/01/2015
# Ingesting dfmc data for: 14/01/2015
# Ingesting dfmc data for: 15/01/2015
# Ingesting dfmc data for: 16/01/2015
# Ingesting dfmc data for: 17/01/2015
# Ingesting dfmc data for: 18/01/2015
# Ingesting dfmc data for: 19/01/2015
# Ingesting dfmc data for: 20/01/2015
# Ingesting dfmc data for: 21/01/2015
# Ingesting dfmc data for: 22/01/2015
# Ingesting dfmc data for: 23/01/2015
# Ingesting dfmc data for: 24/01/2015
# Ingesting dfmc data for: 25/01/2015
# Ingesting dfmc data for: 26/01/2015
# Ingesting dfmc data for: 27/01/2015
# Ingesting dfmc data for: 28/01/2015
# Ingesting dfmc data for: 29/01/2015
# Ingesting dfmc data for: 30/01/2015
# Ingesting dfmc data for: 31/01/2015
# Ingesting dfmc data for: 01/02/2015
# Ingesting dfmc data for: 02/02/2015
# Ingesting dfmc data for: 03/02/2015
# Ingesting dfmc data for: 04/02/2015
# Ingesting dfmc data for: 05/02/2015
# Ingesting dfmc data for: 06/02/2015
# Ingesting dfmc data for: 07/02/2015
# Ingesting dfmc data for: 08/02/2015
# Ingesting dfmc data for: 09/02/2015
# Ingesting dfmc data for: 10/02/2015
# Ingesting dfmc data for: 11/02/2015
# Ingesting dfmc data for: 12/02/2015
# Ingesting dfmc data for: 13/02/2015
# Ingesting dfmc data for: 14/02/2015
# Ingesting dfmc data for: 15/02/2015
# Ingesting dfmc data for: 16/02/2015
# Ingesting dfmc data for: 17/02/2015
# Ingesting dfmc data for: 18/02/2015
# Ingesting dfmc data for: 19/02/2015
# Ingesting dfmc data for: 20/02/2015
# Ingesting dfmc data for: 21/02/2015
# Ingesting dfmc data for: 22/02/2015
# Ingesting dfmc data for: 23/02/2015
# Ingesting dfmc data for: 24/02/2015
# Ingesting dfmc data for: 25/02/2015
# Ingesting dfmc data for: 26/02/2015
# Ingesting dfmc data for: 27/02/2015
# Ingesting dfmc data for: 28/02/2015
# Ingesting dfmc data for: 01/03/2015
# Ingesting dfmc data for: 02/03/2015
# Ingesting dfmc data for: 03/03/2015
# Ingesting dfmc data for: 04/03/2015
# Ingesting dfmc data for: 05/03/2015
# Ingesting dfmc data for: 06/03/2015
# Ingesting dfmc data for: 07/03/2015
# Ingesting dfmc data for: 08/03/2015
# Ingesting dfmc data for: 09/03/2015
# Ingesting dfmc data for: 10/03/2015
# Ingesting dfmc data for: 11/03/2015
# Ingesting dfmc data for: 12/03/2015
# Ingesting dfmc data for: 13/03/2015
# Ingesting dfmc data for: 14/03/2015
# Ingesting dfmc data for: 15/03/2015
# Ingesting dfmc data for: 16/03/2015
# Ingesting dfmc data for: 17/03/2015
# Ingesting dfmc data for: 18/03/2015
# Ingesting dfmc data for: 19/03/2015
# Ingesting dfmc data for: 20/03/2015
# Ingesting dfmc data for: 21/03/2015
# Ingesting dfmc data for: 22/03/2015
# Ingesting dfmc data for: 23/03/2015
# Ingesting dfmc data for: 24/03/2015
# Ingesting dfmc data for: 25/03/2015
# Ingesting dfmc data for: 26/03/2015
# Ingesting dfmc data for: 27/03/2015
# Ingesting dfmc data for: 28/03/2015
# Ingesting dfmc data for: 29/03/2015
# Ingesting dfmc data for: 30/03/2015
# Ingesting dfmc data for: 31/03/2015
# Ingesting dfmc data for: 01/04/2015
# Ingesting dfmc data for: 02/04/2015
# Ingesting dfmc data for: 03/04/2015
# Ingesting dfmc data for: 04/04/2015
# Ingesting dfmc data for: 05/04/2015
# Ingesting dfmc data for: 06/04/2015
# Ingesting dfmc data for: 07/04/2015
# Ingesting dfmc data for: 08/04/2015
# Ingesting dfmc data for: 09/04/2015
# Ingesting dfmc data for: 10/04/2015
# Ingesting dfmc data for: 11/04/2015
# Ingesting dfmc data for: 12/04/2015
# Ingesting dfmc data for: 13/04/2015
# Ingesting dfmc data for: 14/04/2015
# Ingesting dfmc data for: 15/04/2015
# Ingesting dfmc data for: 16/04/2015
# Ingesting dfmc data for: 17/04/2015
# Ingesting dfmc data for: 18/04/2015
# Ingesting dfmc data for: 19/04/2015
# Ingesting dfmc data for: 20/04/2015
# Ingesting dfmc data for: 21/04/2015
# Ingesting dfmc data for: 22/04/2015
# Ingesting dfmc data for: 23/04/2015
# Ingesting dfmc data for: 24/04/2015
# Ingesting dfmc data for: 25/04/2015
# Ingesting dfmc data for: 26/04/2015
# Ingesting dfmc data for: 27/04/2015
# Ingesting dfmc data for: 28/04/2015
# Ingesting dfmc data for: 29/04/2015
# Ingesting dfmc data for: 30/04/2015
# Ingesting dfmc data for: 01/05/2015
# Ingesting dfmc data for: 02/05/2015
# Ingesting dfmc data for: 03/05/2015
# Ingesting dfmc data for: 04/05/2015
# Ingesting dfmc data for: 05/05/2015
# Ingesting dfmc data for: 06/05/2015
# Ingesting dfmc data for: 07/05/2015
# Ingesting dfmc data for: 08/05/2015
# Ingesting dfmc data for: 09/05/2015
# Ingesting dfmc data for: 10/05/2015
# Ingesting dfmc data for: 11/05/2015
# Ingesting dfmc data for: 12/05/2015
# Ingesting dfmc data for: 13/05/2015
# Ingesting dfmc data for: 14/05/2015
# Ingesting dfmc data for: 15/05/2015
# Ingesting dfmc data for: 16/05/2015
# Ingesting dfmc data for: 17/05/2015
